# %%
from sklearn.preprocessing import minmax_scale
from google.colab import drive 
drive.mount('/content/drive')
import pickle
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
 with open("/content/drive/MyDrive/data/ct/ec_ct.pkl", "rb") as fp:
    eclipse_time = pickle.load(fp)
 with open("/content/drive/MyDrive/data/ct/nb_ct.pkl", "rb") as fp:
    netbeans_time = pickle.load(fp)
 with open("/content/drive/MyDrive/data/ct/op_ct.pkl", "rb") as fp:
    openoffice_time = pickle.load(fp)
eclipse_ct = minmax_scale(eclipse_time)
netbeans_ct = minmax_scale(netbeans_time)
openoffice_ct = minmax_scale(openoffice_time)

# %%
 with open("/content/drive/MyDrive/data/pr/ec_pr.pkl", "rb") as fp:
    eclipse_priority = pickle.load(fp)
 with open("/content/drive/MyDrive/data/pr/nb_pr.pkl", "rb") as fp:
    netbeans_priority = pickle.load(fp)
 with open("/content/drive/MyDrive/data/pr/op_pr.pkl", "rb") as fp:
    openoffice_priority = pickle.load(fp)
eclipse_pr = minmax_scale(eclipse_priority)
netbeans_pr = minmax_scale(netbeans_priority)
openoffice_pr = minmax_scale(openoffice_priority)

# %%
 with open("/content/drive/MyDrive/data/sv/ec_sv.pkl", "rb") as fp:
    eclipse_severity = pickle.load(fp)
 with open("/content/drive/MyDrive/data/sv/nb_sv.pkl", "rb") as fp:
    netbeans_severity = pickle.load(fp)
 with open("/content/drive/MyDrive/data/sv/op_sv.pkl", "rb") as fp:
    openoffice_severity = pickle.load(fp)
eclipse_sv = minmax_scale(eclipse_severity)
netbeans_sv = minmax_scale(netbeans_severity)
openoffice_sv = minmax_scale(openoffice_severity)

# %%
with open("/content/drive/MyDrive/data/eclipse_normal/eclipse_ct.pkl", "wb") as fp:
  pickle.dump(eclipse_ct, fp)
with open("/content/drive/MyDrive/data/eclipse_normal/eclipse_sv.pkl", "wb") as fp:
  pickle.dump(eclipse_sv, fp)
with open("/content/drive/MyDrive/data/eclipse_normal/eclipse_pr.pkl", "wb") as fp:
  pickle.dump(eclipse_pr, fp)

# %%
with open("/content/drive/MyDrive/data/netbeans_normal/netbeans_ct.pkl", "wb") as fp:
  pickle.dump(netbeans_ct, fp)
with open("/content/drive/MyDrive/data/netbeans_normal/netbeans_sv.pkl", "wb") as fp:
  pickle.dump(netbeans_sv, fp)
with open("/content/drive/MyDrive/data/netbeans_normal/netbeans_pr.pkl", "wb") as fp:
  pickle.dump(netbeans_pr, fp)

# %%
with open("/content/drive/MyDrive/data/openoffice_normal/openoffice_ct.pkl", "wb") as fp:
  pickle.dump(openoffice_ct, fp)
with open("/content/drive/MyDrive/data/openoffice_normal/openoffice_sv.pkl", "wb") as fp:
  pickle.dump(openoffice_sv, fp)
with open("/content/drive/MyDrive/data/openoffice_normal/openoffice_pr.pkl", "wb") as fp:
  pickle.dump(openoffice_pr, fp)
